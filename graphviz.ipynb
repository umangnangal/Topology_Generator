# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
G.add_node(4)
G.add_node(5)
G.add_edge(4, 5)
plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
# Out:
# /anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
print(type(G))
# Out:
# <class 'networkx.classes.graph.Graph'>

# %%
plt.show()

# %%
from graphviz import *
ps = Graph(name='network-topology', node_attr={'shape': 'box'}, format = 'png')

ps.node('parrot')
ps.node('dead')
ps.edge('parrot', 'dead', headlabel='parrot', taillabel='dead')

ps.render(view = True)
# Out:
# 'network-topology.gv.png'

# %%
print(ps.source)
# Out:
# graph "network-topology" {
# 	node [shape=box]
# 	parrot
# 	dead
# 	parrot -- dead [headlabel=parrot taillabel=dead]
# }

# %%
print(ps.body)
# Out:
# ['\tparrot', '\tdead', '\tparrot -- dead [headlabel=parrot taillabel=dead]']

# %%
label = 'parrot -- dead [headlabel=parrot taillabel=dead]'
if label in [x.strip() for x in ps.body]:
    print('hai bai')
# Out:
# hai bai

# %%
ps.body = ['\t"umang-homewood"', '\t"sunil-ali-22"', '\t"umang-homewood" -- "sunil-ali-22" [headlabel="fc1/27" taillabel="fc1/27"]', '\t"sreejith-homewood"', '\t"umang-homewood" -- "sreejith-homewood" [headlabel="fc1/33" taillabel="fc1/33"]', '\t"sunil-ali-22"', '\t"HW2-Bhargavi"', '\t"sunil-ali-22" -- "HW2-Bhargavi" [headlabel="fc1/17" taillabel="fc1/17"]', '\t"umang-homewood"', '\t"sunil-ali-22" -- "umang-homewood" [headlabel="fc1/27" taillabel="fc1/27"]', '\t"sreejith-homewood"', '\t"umang-homewood"', '\t"sreejith-homewood" -- "umang-homewood" [headlabel="fc1/33" taillabel="fc1/33"]']

# %%
label = '"umang-homewood" -- "sunil-ali-22" [headlabel="fc1/27" taillabel="fc1/27"]'

# %%
if label in [x.strip() for x in ps.body]:
    print('hai bai')
# Out:
# hai bai

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
mail_content = '''Hello,
This is a simple mail. There is only text, no attachments are there The mail is sent using Python SMTP library.
Thank You
'''
#The mail addresses and password
sender_address = 'umangnangal@gmail.com'
sender_pass = 'Treehouse@204'
receiver_address = 'umangnangal96@gmail.com'
#Setup the MIME
message = MIMEMultipart()
message['From'] = sender_address
message['To'] = receiver_address
message['Subject'] = 'A test mail sent by Python. It has an attachment.'   #The subject line
#The body and the attachments for the mail
message.attach(MIMEText(mail_content, 'plain'))
#Create SMTP session for sending the mail
session = smtplib.SMTP('smtp.gmail.com', 587) #use gmail with port
session.starttls() #enable security
session.login(sender_address, sender_pass) #login with mail_id and password
text = message.as_string()
session.sendmail(sender_address, receiver_address, text)
session.quit()
print('Mail Sent')
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-7-293c81518753> in <module>
#      20 session = smtplib.SMTP('smtp.gmail.com', 587) #use gmail with port
#      21 session.starttls() #enable security
# ---> 22 session.login(sender_address, sender_pass) #login with mail_id and password
#      23 text = message.as_string()
#      24 session.sendmail(sender_address, receiver_address, text)
#
# /anaconda3/lib/python3.7/smtplib.py in login(self, user, password, initial_response_ok)
#     728
#     729         # We could not login successfully.  Return result of last attempt.
# --> 730         raise last_exception
#     731
#     732     def starttls(self, keyfile=None, certfile=None, context=None):
#
# /anaconda3/lib/python3.7/smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# --> 721                     initial_response_ok=initial_response_ok)
#     722                 # 235 == 'Authentication successful'
#     723                 # 503 == 'Error: already authenticated'
#
# /anaconda3/lib/python3.7/smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     640         if code in (235, 503):
#     641             return (code, resp)
# --> 642         raise SMTPAuthenticationError(code, resp)
#     643
#     644     def auth_cram_md5(self, challenge=None):
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. Learn more at\n5.7.8  https://support.google.com/mail/?p=BadCredentials w6sm11220741pfj.17 - gsmtp')

# %%
import re
import pandas as pd

stdout = '''
VSAN 1:
--------------------------------------------------------------------------
FCID        TYPE  PWWN                    (VENDOR)        FC4-TYPE:FEATURE
--------------------------------------------------------------------------
0x580020    N     21:00:00:24:ff:3f:1b:e1 (Qlogic)        scsi-fcp:init 
                  [da1]
0x580200    N     24:8f:00:3a:9c:3d:ef:40 (Cisco)         npv 

Total number of entries = 2
'''
database = []
regex = re.compile(r'(0x[0-9]{6})')
for line in stdout:
    print(line)
    mo = re.findall(regex, line)
    database.append(line.split())
        
df = pd.DataFrame(database, columns = ['FCID', 'Type', 'PWWN', 'Vendor', 'FC4-TYPE'])
# Out:
# V
# S
# A
# N
#
# 1
# :
#
#
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
#
#
# F
# C
# I
# D
#
#
#
#
#
#
#
#
# T
# Y
# P
# E
#
#
# P
# W
# W
# N
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (
# V
# E
# N
# D
# O
# R
# )
#
#
#
#
#
#
#
#
# F
# C
# 4
# -
# T
# Y
# P
# E
# :
# F
# E
# A
# T
# U
# R
# E
#
#
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
#
#
# 0
# x
# 5
# 8
# 0
# 0
# 2
# 0
#
#
#
#
# N
#
#
#
#
#
# 2
# 1
# :
# 0
# 0
# :
# 0
# 0
# :
# 2
# 4
# :
# f
# f
# :
# 3
# f
# :
# 1
# b
# :
# e
# 1
#
# (
# Q
# l
# o
# g
# i
# c
# )
#
#
#
#
#
#
#
#
# s
# c
# s
# i
# -
# f
# c
# p
# :
# i
# n
# i
# t
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
# d
# a
# 1
# ]
#
#
# 0
# x
# 5
# 8
# 0
# 2
# 0
# 0
#
#
#
#
# N
#
#
#
#
#
# 2
# 4
# :
# 8
# f
# :
# 0
# 0
# :
# 3
# a
# :
# 9
# c
# :
# 3
# d
# :
# e
# f
# :
# 4
# 0
#
# (
# C
# i
# s
# c
# o
# )
#
#
#
#
#
#
#
#
#
# n
# p
# v
#
#
#
#
#
# T
# o
# t
# a
# l
#
# n
# u
# m
# b
# e
# r
#
# o
# f
#
# e
# n
# t
# r
# i
# e
# s
#
# =
#
# 2
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-12c7bed44c0a> in <module>
#      20     database.append(line.split())
#      21
# ---> 22 df = pd.DataFrame(database, columns = ['FCID', 'Type', 'PWWN', 'Vendor', 'FC4-TYPE'])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     402     if isinstance(data[0], (list, tuple)):
#     403         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# --> 404                                dtype=dtype)
#     405     elif isinstance(data[0], compat.Mapping):
#     406         return _list_of_dict_to_arrays(data, columns,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     434         content = list(lib.to_object_array(data).T)
#     435     return _convert_object_array(content, columns, dtype=dtype,
# --> 436                                  coerce_float=coerce_float)
#     437
#     438
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     490             raise AssertionError('{col:d} columns passed, passed data had '
#     491                                  '{con} columns'.format(col=len(columns),
# --> 492                                                         con=len(content)))
#     493
#     494     # provide soft conversion of object dtypes
#
# AssertionError: 5 columns passed, passed data had 1 columns
